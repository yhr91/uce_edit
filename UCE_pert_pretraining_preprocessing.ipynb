# %%
import scanpy as sc
import argparse
from evaluate import AnndataProcessor
from accelerate import Accelerator
import glob
import numpy as np

default_arguments = {
    # Anndata Processing Arguments
    'adata_path': '',
    'dir': "./",
    'species': "human",
    'filter': True,
    'skip': True,

    # Model Arguments
    'model_loc': None,
    'batch_size': 25,
    'pad_length': 1536,
    'pad_token_idx': 0,
    'chrom_token_left_idx': 1,
    'chrom_token_right_idx': 2,
    'cls_token_idx': 3,
    'CHROM_TOKEN_OFFSET': 143574,
    'sample_size': 1024,
    'CXG': True,
    'nlayers': 4,
    'output_dim': 1280,
    'd_hid': 5120,
    'token_dim': 5120,
    'multi_gpu': False,

    # Misc Arguments
    'spec_chrom_csv_path': "./model_files/species_chrom.csv",
    'token_file': "./model_files/all_tokens.torch",
    'protein_embeddings_dir': "./model_files/protein_embeddings/",
    'offset_pkl_path': "./model_files/species_offsets.pkl"
}
args = argparse.Namespace(**default_arguments)

accelerator = Accelerator(project_dir=args.dir)

# %%
for f in glob.glob('/dfs/project/virtual-cell-data/train_data/perturb/cleaned/*/*/*.h5ad'):
    if 'scaling' not in f and 'replogle' not in f and 'preprocessed' not in f:
        adata_name = '_'.join(f.split('/')[-3:]).split('_adata.h5ad')[0]
        args.adata_path = f
        processor = AnndataProcessor(args, accelerator, name = adata_name)
        processor.preprocess_anndata()
        processor.generate_idxs()
# Out:
# Using sample 4 layer model
# Proccessing dixit_K562_33
# /dfs/project/virtual-cell-data/train_data/perturb/cleaned/dixit/K562//33_adata.h5ad
# 3747.0
# dixit_K562_33 (51898, 12953)
# Wrote Shapes Dict
# 12952
# Max Code: 613
# Proccessing peipei_CD8+T_33
# /dfs/project/virtual-cell-data/train_data/perturb/cleaned/peipei/CD8+T//33_adata.h5ad
# 8028.0
# peipei_CD8+T_33 (116676, 13936)
# Wrote Shapes Dict
# 13936
# Max Code: 613
# Proccessing ursu_A549_33_TPS3
# /dfs/project/virtual-cell-data/train_data/perturb/cleaned/ursu/A549//33_TPS3_adata.h5ad
# 4757.0
# ursu_A549_33_TPS3 (12702, 10854)
# Wrote Shapes Dict
# 10854
# Max Code: 613
# Proccessing ursu_A549_33_KRAS
# /dfs/project/virtual-cell-data/train_data/perturb/cleaned/ursu/A549//33_KRAS_adata.h5ad
# 3540.0
# ursu_A549_33_KRAS (11633, 10774)
# Wrote Shapes Dict
# 10774
# Max Code: 613
# Proccessing frangieh_TIL_33_perturb_CITE
# /dfs/project/virtual-cell-data/train_data/perturb/cleaned/frangieh/TIL//33_perturb_CITE_adata.h5ad
# 4437.0
# frangieh_TIL_33_perturb_CITE (218331, 16236)

# %% [markdown]
# ### Replogle essentials

# %%
##replogle_datasets = ['/dfs/project/perturb-gnn/datasets/replogle2022_unpublished/jurkat_raw_singlecell_01_varnames_mod.h5ad',
##                     '/dfs/project/perturb-gnn/datasets/replogle2022_unpublished/hepg2_raw_singlecell_01_varnames_mod_fix.h5ad']


##replogle_datasets = ['/dfs/project/perturb-gnn/datasets/replogle/anndata/rpe1_raw_singlecell_01_varnames_mod.h5ad',
##                     '/dfs/project/perturb-gnn/datasets/replogle/anndata/K562_essential_raw_singlecell_01_varnames_mod.h5ad']

# %%
for f in replogle_datasets:
    args.adata_path = f
    processor = AnndataProcessor(args, accelerator)
    processor.preprocess_anndata()
    processor.generate_idxs()
# Out:
# Using sample 4 layer model
# Proccessing rpe1_raw_singlecell_01_varnames_mod
# /dfs/project/perturb-gnn/datasets/replogle/anndata//rpe1_raw_singlecell_01_varnames_mod.h5ad
# 3061.0
# rpe1_raw_singlecell_01_varnames_mod (247914, 8427)
# Wrote Shapes Dict
# 8426
# Max Code: 612
# Proccessing K562_essential_raw_singlecell_01_varnames_mod
# /dfs/project/perturb-gnn/datasets/replogle/anndata//K562_essential_raw_singlecell_01_varnames_mod.h5ad
# 2277.0
# K562_essential_raw_singlecell_01_varnames_mod (310385, 8105)
# Wrote Shapes Dict
# 8103
# Max Code: 612
# Proccessing K562_gwps_raw_singlecell_01
# /dfs/project/perturb-gnn/datasets/replogle/anndata//K562_gwps_raw_singlecell_01.h5ad
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 4
#       2 args.adata_path = f
#       3 processor = AnndataProcessor(args, accelerator)
# ----> 4 processor.preprocess_anndata()
#       5 processor.generate_idxs()
#
# File /dfs/user/yhr/Arc/uce_edit/evaluate.py:97, in AnndataProcessor.preprocess_anndata(self)
#      94 def preprocess_anndata(self):
#      95     if self.accelerator.is_main_process:
#      96         self.adata, num_cells, num_genes = \
# ---> 97             process_raw_anndata(self.row,
#      98                                 self.h5_folder_path,
#      99                                 self.npz_folder_path,
#     100                                 self.scp,
#     101                                 self.args.skip,
#     102                                 self.args.filter,
#     103                                 root=self.adata_root_path,
#     104                                 name=self.name)
#     105         if (num_cells is not None) and (num_genes is not None):
#     106             self.save_shapes_dict(self.name, num_cells, num_genes,
#     107                                    self.shapes_dict_path)
#
# File /dfs/user/yhr/Arc/uce_edit/data_proc/data_utils.py:214, in process_raw_anndata(row, h5_folder_path, npz_folder_path, scp, skip, additional_filter, root, name, save_proc)
#     210     sc.pp.filter_genes(ad, min_cells=10)
#     211     sc.pp.filter_cells(ad, min_genes=25)
# --> 214 dataset, adata = anndata_to_sc_dataset(ad, species=species, labels=labels, covar_col=covar_col, hv_genes=None)
#     215 adata = adata.copy()
#     217 if additional_filter:
#
# File /dfs/user/yhr/Arc/uce_edit/data_proc/data_utils.py:123, in anndata_to_sc_dataset(adata, species, labels, covar_col, hv_genes, embedding_model)
#     114 def anndata_to_sc_dataset(adata:sc.AnnData,
#     115                                  species:str="human",
#     116                                  labels:list=[],
#    (...)
#     121
#     122     # Subset to just genes we have embeddings for
# --> 123     adata, protein_embeddings = load_gene_embeddings_adata(
#     124         adata=adata,
#     125         species=[species],
#     126         embedding_model=embedding_model
#     127     )
#     129     if hv_genes is not None:
#     130         sc.pp.highly_variable_genes(adata, flavor='seurat_v3', n_top_genes=hv_genes)  # Expects Count Data
#
# File /dfs/user/yhr/Arc/uce_edit/data_proc/gene_embeddings.py:73, in load_gene_embeddings_adata(adata, species, embedding_model)
#      70 adata = adata[:, adata.var_names.isin(genes_to_use)]
#      72 # Set up dictionary mapping species to gene embedding matrix (num_genes, embedding_dim)
# ---> 73 species_to_gene_embeddings = {
#      74     species_name: torch.stack([
#      75         species_to_gene_symbol_to_embedding[species_name][gene_symbol.lower()]
#      76         for gene_symbol in adata.var_names
#      77     ])
#      78     for species_name in species_names
#      79 }
#      81 return adata, species_to_gene_embeddings
#
# File /dfs/user/yhr/Arc/uce_edit/data_proc/gene_embeddings.py:74, in <dictcomp>(.0)
#      70 adata = adata[:, adata.var_names.isin(genes_to_use)]
#      72 # Set up dictionary mapping species to gene embedding matrix (num_genes, embedding_dim)
#      73 species_to_gene_embeddings = {
# ---> 74     species_name: torch.stack([
#      75         species_to_gene_symbol_to_embedding[species_name][gene_symbol.lower()]
#      76         for gene_symbol in adata.var_names
#      77     ])
#      78     for species_name in species_names
#      79 }
#      81 return adata, species_to_gene_embeddings
#
# RuntimeError: stack expects a non-empty TensorList

# %% [markdown]
# ### Replogle genome-wide

# %%
replogle_datasets = ['/dfs/project/virtual-cell-data/train_data/perturb/cleaned/replogle/K562/33_part1_adata.h5ad',
                    '/dfs/project/virtual-cell-data/train_data/perturb/cleaned/replogle/K562/33_part2_adata.h5ad'
                    ]

# %%
for f in replogle_datasets:
    adata_name = '_'.join(f.split('/')[-3:]).split('_adata.h5ad')[0]
    args.adata_path = f
    processor = AnndataProcessor(args, accelerator, name = adata_name)
    processor.preprocess_anndata()
    processor.generate_idxs()
# Out:
# Proccessing replogle_K562_33_part1
# /dfs/project/virtual-cell-data/train_data/perturb/cleaned/replogle/K562//33_part1_adata.h5ad

# %% [markdown]
# ### McFaline

# %%
f = '/dfs/project/virtual-cell-data/train_data/perturb/mcfaline-figueroa/mcfaline23_gxe_processed.h5ad'

# %%
args.adata_path = f
processor = AnndataProcessor(args, accelerator)
processor.preprocess_anndata()
processor.generate_idxs()
# Out:
# Using sample 4 layer model
# Proccessing mcfaline23_gxe_processed
# /dfs/project/virtual-cell-data/train_data/perturb/mcfaline-figueroa//mcfaline23_gxe_processed.h5ad
# 17362.0
# mcfaline23_gxe_processed (878226, 17809)
# Wrote Shapes Dict
# PE Idx, Chrom and Starts files already created

# %% [markdown]
# ## Setting up training data

# %%
import glob
import pickle
import torch

shape_dicts_files = glob.glob('/dfs/user/yhr/Arc/uce_edit/*_shapes_dict.pkl')
chroms_files = glob.glob('/dfs/user/yhr/Arc/uce_edit/*_chroms.pkl')
starts_files = glob.glob('/dfs/user/yhr/Arc/uce_edit/*_starts.pkl')
pe_idxs_files = glob.glob('/dfs/user/yhr/Arc/uce_edit/*_pe_idx.torch')

shape_dicts = {}
chroms = {}
starts = {}
pe_idxs = {}

for f in shape_dicts_files:
    with open(f, 'rb') as file:
        read_in = pickle.load(file)
    shape_dicts.update(read_in)
    
for f in chroms_files:
    with open(f, 'rb') as file:
        read_in = pickle.load(file)
    chroms.update(read_in)
    
for f in starts_files:
    with open(f, 'rb') as file:
        read_in = pickle.load(file)
    starts.update(read_in)
    
for f in pe_idxs_files:
    read_in = torch.load(f)
    pe_idxs.update(read_in)

# %%
## Total number of additional training cells

sum([x[0] for x in shape_dicts.values()])
# Out:
# 6214929

# %%
with open('pert_shapes_dict.pkl', 'wb') as f:
    pickle.dump(shape_dicts, f)
    
with open('pert_chroms.pkl', 'wb') as f:
    pickle.dump(chroms, f)
    
with open('pert_starts.pkl', 'wb') as f:
    pickle.dump(starts, f)
    
torch.save(pe_idxs, 'pert_pe_idx.torch')

# %%
df = pd.DataFrame.from_dict(shape_dicts, orient='index').reset_index()
df = df.rename(columns={0:'num_cells', 1:'num_genes', 'index':'names'})
df['path'] = [x +'.h5ad' for x in df['names']]
df['census'] = 'no'
df['species'] = 'human'
df['species'] = df['names'].map(species_map)

# %%
## Add counts data to dataset_file

import pandas as pd
all_train_datasets = pd.read_csv('/dfs/project/uce/response/full_train_datasets_pert.csv',  index_col = 0)
all_train_datasets = pd.concat([df, all_train_datasets])
all_train_datasets.to_csv('/dfs/project/uce/response/full_train_datasets_pert.csv')

# %%
## Add other params: starts

with open('/lfs/local/0/yhr/dataset_to_chroms_new.pkl', 'rb') as f:
    loaded = pickle.load(f)
    loaded.update(chroms)
    
with open('/lfs/local/0/yhr/dataset_to_chroms_new.pkl', 'wb') as f:
    pickle.dump(loaded, f)

# %%
## Add other params: chroms

with open('/lfs/local/0/yhr/dataset_to_starts_new.pkl', 'rb') as f:
    loaded = pickle.load(f)
    loaded.update(starts)
    
with open('/lfs/local/0/yhr/dataset_to_starts_new.pkl', 'wb') as f:
    pickle.dump(loaded, f)

# %%
## Add other params: protein idxs

loaded = torch.load('/lfs/local/0/yhr/reduced_datasets_to_pe_chrom_5120_new.torch')
loaded.update(pe_idxs)

torch.save(loaded, '/lfs/local/0/yhr/reduced_datasets_to_pe_chrom_5120_new.torch')

# %%
np.sort(list(loaded.keys()))
# Out:
# array(['00476f9f-ebc1-4b72-b541-32f912ce36ea',
#        '01209dce-3575-4bed-b1df-129f57fbc031',
#        '0129dbd9-a7d3-4f6b-96b9-1da155a93748',
#        '019c7af2-c827-4454-9970-44d5e39ce068',
#        '01ad3cd7-3929-4654-84c0-6db05bd5fd59',
#        '03d38670-1444-4001-bc53-9936e61d9b20',
#        '047d57f2-4d14-45de-aa98-336c6f583750',
#        '07854d9c-5375-4a9b-ac34-fa919d3c3686',
#        '07b1d7c8-5c2e-42f7-9246-26f746cd6013',
#        '090da8ea-46e8-40df-bffc-1f78e1538d27',
#        '095940cb-7422-4510-96e2-cbafd961eb88',
#        '0b4a15a7-4e9e-4555-9733-2423e5c66469',
#        '0b75c598-0893-4216-afe8-5414cab7739d',
#        '0ba636a1-4754-4786-a8be-7ab3cf760fd6',
#        '0c774045-26a7-40f8-9b07-6742d3c771c0',
#        '0ee5ae70-c3f5-473f-bd1c-287f4690ffc5',
#        '0f4865d5-8000-4f68-8ac7-f5efea9e5e70',
#        '1185a7d3-a9c1-4280-9ba5-d61895b15cac',
#        '11ff73e8-d3e4-4445-9309-477a2c5be6f6',
#        '124744b8-4681-474a-9894-683896122708',
#        '12967895-3d58-4e93-be2c-4e1bcf4388d5',
#        '182f6a56-7360-4924-a74e-1772e07b3031',
#        '18500fcd-9960-49cb-8a8e-7d868dc14efe',
#        '18e2a8c5-33f7-455e-a58a-b2ba6921db27',
#        '19b21f40-db42-4a71-a0d6-913e83b17784',
#        '1a018108-b4b6-457b-ba15-046d5e98c169',
#        'a13bda79-9134-46c9-9ed1-a2858be9aafe',
#        'a19b218b-1c0a-4618-b41f-7c216c623ec6',
#        'a1b9c51e-a408-4f7f-bccb-abefe20ae2a5',
#        'a37f857c-779f-464e-9310-3db43a1811e7',
#        'a4116666-d295-4443-a174-0acc283f92c4',
#        'a43aa46b-bd16-47fe-bc3e-19a052624e79',
#        'a539c7af-fb65-44b1-8812-000b097eac99',
#        'a59ba9fa-1407-4f15-8c56-d3637421570d',
#        'a5b5d1f3-dd8b-44f6-a685-15f0f741c062',
#        'a5d95a42-0137-496f-8a60-101e17f263c8',
#        'a7b4f565-691d-43ea-bf4a-d2d1d52bb4b4',
#        'a84face4-eb30-4f43-994f-c6a13a097808',
#        'aad97cb5-f375-45ef-ae9d-178e7f5d5180',
#        'ac2fea99-ce08-4fca-8d03-a19f37bf21a3',
#        'acae7679-d077-461c-b857-ee6ccfeb267f', 'adamson_K562_33',
#        'adda0684-f8ea-4403-b393-2a25607077c4',
#        'ae4f8ddd-cac9-4172-9681-2175da462f2e',
#        'af8b241a-c72c-4470-b1a4-80e7336c6ab6',
#        'b07fb54c-d7ad-4995-8bb0-8f3d8611cabe',
#        'b0e547f0-462b-4f81-b31b-5b0a5d96f537',
#        'b252b015-b488-4d5c-b16e-968c13e48a2c',
#        'b46237d1-19c6-4af2-9335-9854634bad16',
#        'b693123e-95e6-4331-8b50-f367489a767e',
#        'b8681124-aabf-4904-b9c9-66d834bf5bba',
#        'babbf9f3-f482-45a5-ba76-c41f4c2f503e',
#        'bac09168-940b-4b11-8d55-b4955f80b98d',
#        'bc7260e0-54cf-4b0b-823d-93f5b850f757',
#        'bd65a70f-b274-4133-b9dd-0d1431b6af34',
#        'be39785b-67cb-4177-be19-a40ee3747e45',
#        'be884a28-0eac-4eca-9c23-1294a93cf56e', 'brain_zebrafish',
#        'briggs_klein_frog', 'briggs_klein_zebrafish',
#        'c05e6940-729c-47bd-a2a6-6ce3730c4919',
#        'c05fb583-eb2f-4e3a-8e74-f9bd6414e418',
#        'c2876b1b-06d8-4d96-a56b-5304f815b99a',
#        'c2a461b1-0c15-4047-9fcb-1f966fe55100',
#        'c2aad8fc-b63b-4f9b-9cfd-baf7bc9c1771',
#        'c4dd26a8-d956-4bee-a233-44b573f2ce27',
#        'c5cfa2b7-abb1-4a50-908f-707b54ca606b',
#        'c7775e88-49bf-4ba2-a03b-93f00447c958',
#        'c7856243-c59a-4b70-8ce7-25b94c2d9da1',
#        'ca20e2ac-5676-4158-b5d0-0c2b15898b19',
#        'ccfdcad0-7104-46b9-addf-fd66a2a15907',
#        'cda2c8cd-be1c-42e5-b2cd-162caa1c4ce7',
#        'cfa3c355-ee77-4fc8-9a00-78e61d23024c', 'colorectal_cancer_human',
#        'congenital_heart_human', 'covid_broad_heart_human',
#        'covid_broad_kidney_human', 'covid_broad_liver_human',
#        'covid_broad_lung_human', 'cui_B_cell_33', 'cui_ILC_33',
#        'cui_Macrophage_33', 'cui_MigDC_33', 'cui_Monocyte_33',
#        'cui_NK_cell_33', 'cui_Neutrophil_33', 'cui_T_cell_CD4_33',
#        'cui_T_cell_CD8_33', 'cui_T_cell_gd_33', 'cui_Treg_33',
#        'cui_cDC1_33', 'cui_cDC2_33', 'cui_ceTAC_33', 'cui_pDC_33',
#        'd02287f3-408b-438d-9131-999e460cbd0e',
#        'd1207c81-7309-43a7-a5a0-f4283670b62b',
#        'd2514440-d747-4d8d-b2c7-b58ef8b71fbe',
#        'd288b10a-643e-44bd-b451-96e9588b2ee5',
#        'd2b5efc1-14c6-4b5f-bd98-40f9084872d7',
#        'd319af7f-be2e-441e-8caa-3b8a88480e89',
#        'd41f45c1-1b7b-4573-a998-ac5c5acb1647',
#        'd4e69e01-3ba2-4d6b-a15d-e7048f78f22e',
#        'd5452b83-7c3d-4d7c-ab7a-c7fece7196c5',
#        'd582f63a-3c88-4e38-8cd3-8682dbe40f64',
#        'd5c67a4e-a8d9-456d-a273-fa01adb1b308',
#        'd6a5b240-cc8f-45c1-ad36-2fc291e15e8e',
#        'd6dfdef1-406d-4efb-808c-3c5eddbfe0cb',
#        'd7291f04-fbbb-4d65-990a-f01fa44e915b',
#        'd7d7e89c-c93a-422d-8958-9b4a90b69558',
#        'd7dcfd8f-2ee7-4385-b9ac-e074c23ed190',
#        'd8da613f-e681-4c69-b463-e94f5e66847f', 'darrah_seder_tb_macaM',
#        'db1d2c1b-2ee1-45d5-9d53-69a327cd77e6',
#        'dbb4e1ed-d820-4e83-981f-88ef7eb55a35',
#        'dd03ce70-3243-4c96-9561-330cc461e4d7',
#        'ddb22b3d-a75c-4dd1-9730-dff7fc8ca530',
#        'de2c780c-1747-40bd-9ccf-9588ec186cee',
#        'de94c504-4b58-4f42-b68d-74a8e4892f0e',
#        'de985818-285f-4f59-9dbd-d74968fddba3', 'development_macaf',
#        'dixit_K562_33', 'e04daea4-4412-45b5-989e-76a9be070a89',
#        'e067e5ca-e53e-485f-aa8e-efd5435229c8',
#        'e0ed3c55-aff6-4bb7-b6ff-98a2d90b890c',
#        'e1f595f6-ba2c-495e-9bee-7056f116b1e4',
#        'e40c6272-af77-4a10-9385-62a398884f27',
#        'e5b1115b-a486-49bb-bda3-8261822836e0',
#        'e6dad530-418b-47f9-af6e-472e56a7b314',
#        'e84f2780-51e8-4cfa-8aa0-13bbfef677c7',
#        'e8681d74-ac9e-4be5-be14-1cf1bbd54dd7',
#        'ea01c125-67a7-4bd3-a8b0-e1b53a011b7e',
#        'ebc2e1ff-c8f9-466a-acf4-9d291afaf8b3',
#        'ec6ceff8-c8bc-488d-b6bf-30df2fa92169',
#        'ecd9230d-c571-4dab-abd3-8b54c74833f0',
#        'ed11cc3e-2947-407c-883c-c53b043917c3',
#        'ed33c203-233a-476a-a56b-28da945fdd32',
#        'ed5d841d-6346-47d4-ab2f-7119ad7e3a35',
#        'edc8d3fe-153c-4e3d-8be0-2108d30f8d70',
#        'ee195b7d-184d-4dfa-9b1c-51a7e601ac11', 'embryonic_stem_cells',
#        'f15e263b-6544-46cb-a46e-e33ab7ce8347',
#        'f20f44ef-a0d4-4d94-87de-037fd47141f0',
#        'f32c2c13-bb1a-4ffd-a457-60b64ecfa4cb',
#        'f3565fda-499a-4d20-bd92-563c09954c42',
#        'f502c312-05dc-4fd4-a762-92a63e92b539',
#        'f512b8b6-369d-4a85-a695-116e0806857f',
#        'f5a04dff-d394-4023-8811-65494e8bb11d',
#        'f6d9f2ad-5ec7-4d53-b7f0-ceb0e7bcd181',
#        'f7a068f1-0fdb-48e8-8029-db870ff11d9e',
#        'f801b7a9-80a6-4d09-9161-71474deb58ae',
#        'f8dda921-5fb4-4c94-a654-c6fc346bfd6d',
#        'f9034091-2e8f-4ac6-9874-e7b7eb566824',
#        'f9846bb4-784d-4582-92c1-3f279e4c6f0c',
#        'fa554686-fc07-44dd-b2de-b726d82d26ec',
#        'fa8605cf-f27e-44af-ac2a-476bee4410d3',
#        'farnsworth_miller_dev_zebrafish',
#        'fbf173f9-f809-4d84-9b65-ae205d35b523',
#        'fd072bc3-2dfb-46f8-b4e3-467cb3223182',
#        'fe1a73ab-a203-45fd-84e9-0f7fd19efcbd',
#        'fe4b89d5-461e-440c-a5a8-621b37b122c0',
#        'ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded',
#        'frangieh_TIL_33_perturb_CITE',
#        'hepg2_raw_singlecell_01_varnames_mod_fix', 'intestine_zebrafish',
#        'islet_pig', 'jiang_A549_33_IFNB', 'jiang_A549_33_IFNG',
#        'jiang_A549_33_INS', 'jiang_A549_33_TGFB', 'jiang_A549_33_TNFA',
#        'jiang_BXPC3_33_IFNB', 'jiang_BXPC3_33_IFNG', 'jiang_BXPC3_33_INS',
#        'jiang_BXPC3_33_TGFB', 'jiang_BXPC3_33_TNFA', 'jiang_HAP1_33_IFNB',
#        'jiang_HAP1_33_IFNG', 'jiang_HAP1_33_INS', 'jiang_HAP1_33_TGFB',
#        'jiang_HAP1_33_TNFA', 'jiang_HT29_33_IFNB', 'jiang_HT29_33_IFNG',
#        'jiang_HT29_33_INS', 'jiang_HT29_33_TGFB', 'jiang_HT29_33_TNFA',
#        'jiang_K562_33_IFNB', 'jiang_K562_33_IFNG', 'jiang_K562_33_INS',
#        'jiang_K562_33_TGFB', 'jiang_K562_33_TNFA', 'jiang_MCF7_33_IFNB',
#        'jiang_MCF7_33_IFNG', 'jiang_MCF7_33_INS', 'jiang_MCF7_33_TGFB',
#        'jiang_MCF7_33_TNFA', 'jurkat_raw_singlecell_01_varnames_mod',
#        'mcfaline23_gxe_processed', 'microbe_intestine_zebrafish',
#        'norman_K562_33', 'pancreatic_ductal_adenocarcinoma_human',
#        'parkinsons_macaF', 'peipei_CD8+T_33', 'replogle_K562_33_part1',
#        'replogle_K562_33_part2', 'rpe1_raw_singlecell_01_varnames_mod',
#        'schmidt_cell_type_33_needslabels', 'tabula_microcebus',
#        'tabula_muris', 'thymoma_human', 'ursu_A549_33_KRAS',
#        'ursu_A549_33_TPS3', 'yan_sanes_human_eye', 'zebrafish_cancer',
#        'zebrahub', 'zyl_sanes_glaucoma_human', 'zyl_sanes_glaucoma_macaF',
#        'zyl_sanes_glaucoma_macaM', 'zyl_sanes_glaucoma_mouse',
#        'zyl_sanes_glaucoma_pig'], dtype='<U45')

# %%
loaded['K562_essential_raw_singlecell_01_varnames_mod']
# Out:
# tensor([24381, 21976, 20529,  ..., 23680, 23673, 22831])
